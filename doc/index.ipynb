# %%
import imagen
# %load_ext dataviews.ipython
# Out:
# Welcome to the Dataviews IPython extension! (http://ioam.github.io/imagen/)
# Available magics: %opts, %params, %view, %%labels, %%opts, %%view

# %%
gaussian=imagen.Gaussian(xdensity=60,ydensity=60,size=0.3,aspect_ratio=1.0)[:]
gaussian
# Out:
# SheetView(bounds=BoundingBox(radius=0.5), cyclic_range=None, label='Gaussian Pattern', metadata={}, name='SheetView00023', roi_bounds=None, title='{label}')

# %%
# %opts Pattern_SheetView cmap='jet'
gaussian
# Out:
# SheetView(bounds=BoundingBox(radius=0.5), cyclic_range=None, label='Gaussian Pattern', metadata={}, name='SheetView00023', roi_bounds=None, title='{label}')
